# %%
supply_model = joblib.load(
    r"D:\Guvi\Projects\ride_flow_ai\models\supply_prediction_model.pkl"
)

# %%
import joblib

model = joblib.load(
    r"D:\Guvi\Projects\ride_flow_ai\models\supply_prediction_model.pkl"
)

print(model.feature_names_in_)
print(model.n_features_in_)
# Out:
# ['PULocationID' 'pickup_hour']
# 2

# %%
import joblib

model = joblib.load(
    r"D:\Guvi\Projects\ride_flow_ai\models\cancellation_prediction_model.pkl"
)

print("Features:", model.feature_names_in_)
print("Number:", model.n_features_in_)
# Out:
# Features: ['ETA' 'traffic_level' 'driver_rating' 'surge_multiplier' 'trip_distance'
#  'fare_amount']
# Number: 6
